# %%
#01 Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
x = 2

# %%
x
# Out:
# 2

# %%
print(x)
# Out:
# 2

# %%
type(x)
# Out:
# int

# %%
y = 5.678

# %%
type(y)
# Out:
# float

# %%
z = 'Brazil'

# %%
type(z)
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
print(x)
# Out:
# 2

# %%
x + 4
# Out:
# 6

# %%
x + y
# Out:
# 7.678

# %%
x = x + 4

# %%
print(x)
# Out:
# 6

# %%
x == y
# Out:
# False

# %%
type( x == y)
# Out:
# bool

# %% [markdown]
# Python data types

# %%
# Method 1

# %%
a = 30

# %%
b = 70

# %%
a + b
# Out:
# 100

# %%
# Method 2

# %%
x = 200

# %%
y = 100

# %%
x - y
# Out:
# 100

# %%
# Method 3

# %%
m = 80
n = 25
l = 5

# %%
m + n - l
# Out:
# 100

# %%
# 2 Floating-points variables

# %%
a = 25.5 
b = 2.5

# %%
a / b
# Out:
# 10.2

# %%
# 3 Construct a short word

# %%
m1 = 'Maria'
m2 = 'Tirado'

# %%
m1 + m2
# Out:
# 'MariaTirado'

# %%
# 4 two short sentences

# %%
s1 = 'I am'
s2 = 'learning'
s3 = 'Python'

# %%
s1 + s2 + s3
# Out:
# 'I amlearningPython'

# %%
f1 = 'and'
f2 = 'I'
f3 = 'like it'

# %%
f1 + f2 + f3
# Out:
# 'andIlike it'
